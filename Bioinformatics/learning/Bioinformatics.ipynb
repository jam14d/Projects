# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.83-cp38-cp38-macosx_10_9_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 12.1 MB/s eta 0:00:0031m11.6 MB/s eta 0:00:01
# Collecting numpy
#   Downloading numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 41.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: numpy, biopython
# Successfully installed biopython-1.83 numpy-1.24.4
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
from Bio import SeqIO
print("Biopython is installed and working!")
# Out:
# Biopython is installed and working!

# %%
import sys
print(sys.executable)
# Out:
# /Users/jamieannemortel/Projects/bioenv/bin/python

# %%
pip install jupyter_contrib_nbextensions
# Out:
# Collecting jupyter_contrib_nbextensions
#   Downloading jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 7.1 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... done
# Collecting ipython_genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyter_contrib_core>=0.3.3
#   Downloading jupyter_contrib_core-0.4.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jupyter_core in ./bioenv/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (5.7.2)
# Collecting jupyter_highlight_selected_word>=0.1.1
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jupyter_nbextensions_configurator>=0.4.0
#   Downloading jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl (466 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.9/466.9 kB 8.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: nbconvert>=6.0 in ./bioenv/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in ./bioenv/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (7.3.2)
# Requirement already satisfied: tornado in ./bioenv/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.4.2)
# Requirement already satisfied: traitlets>=4.1 in ./bioenv/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Collecting lxml
#   Downloading lxml-5.3.0-cp38-cp38-macosx_10_9_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 8.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: setuptools in ./bioenv/lib/python3.8/site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (56.0.0)
# Requirement already satisfied: jupyter-server in ./bioenv/lib/python3.8/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.14.2)
# Requirement already satisfied: pyyaml in ./bioenv/lib/python3.8/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.1)
# Requirement already satisfied: importlib-metadata>=3.6 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (8.5.0)
# Requirement already satisfied: beautifulsoup4 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.13.3)
# Requirement already satisfied: defusedxml in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: nbformat>=5.7 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.4)
# Requirement already satisfied: nbclient>=0.5.0 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.10.1)
# Requirement already satisfied: pygments>=2.4.1 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.19.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: markupsafe>=2.0 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.5)
# Requirement already satisfied: packaging in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (24.2)
# Requirement already satisfied: jupyterlab-pygments in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: jinja2>=3.0 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.5)
# Requirement already satisfied: platformdirs>=2.5 in ./bioenv/lib/python3.8/site-packages (from jupyter_core->jupyter_contrib_nbextensions) (4.3.6)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./bioenv/lib/python3.8/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in ./bioenv/lib/python3.8/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.3.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./bioenv/lib/python3.8/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: webencodings in ./bioenv/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in ./bioenv/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.17.0)
# Requirement already satisfied: tinycss2<1.3,>=1.1.0 in ./bioenv/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: zipp>=3.20 in ./bioenv/lib/python3.8/site-packages (from importlib-metadata>=3.6->nbconvert>=6.0->jupyter_contrib_nbextensions) (3.20.2)
# Requirement already satisfied: pyzmq>=24 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (26.2.1)
# Requirement already satisfied: prometheus-client>=0.9 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.21.1)
# Requirement already satisfied: overrides>=5.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.3)
# Requirement already satisfied: anyio>=3.1.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.5.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (8.6.3)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.5.3)
# Requirement already satisfied: terminado>=0.8.3 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./bioenv/lib/python3.8/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: importlib-resources>=1.4 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (6.4.5)
# Requirement already satisfied: async-lru>=1.0.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: ipykernel>=6.5.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.5)
# Requirement already satisfied: httpx>=0.25.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.28.1)
# Requirement already satisfied: tomli>=1.2.2 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.1)
# Requirement already satisfied: babel>=2.10 in ./bioenv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.17.0)
# Requirement already satisfied: jsonschema>=4.18.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (4.23.0)
# Requirement already satisfied: requests>=2.31 in ./bioenv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.3)
# Requirement already satisfied: json5>=0.9.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.10.0)
# Requirement already satisfied: typing-extensions in ./bioenv/lib/python3.8/site-packages (from mistune<4,>=2.0.3->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.2)
# Requirement already satisfied: fastjsonschema>=2.15 in ./bioenv/lib/python3.8/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.21.1)
# Requirement already satisfied: soupsieve>1.2 in ./bioenv/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.6)
# Requirement already satisfied: sniffio>=1.1 in ./bioenv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./bioenv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./bioenv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.2.2)
# Requirement already satisfied: argon2-cffi-bindings in ./bioenv/lib/python3.8/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in ./bioenv/lib/python3.8/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2025.1)
# Requirement already satisfied: httpcore==1.* in ./bioenv/lib/python3.8/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (1.0.7)
# Requirement already satisfied: certifi in ./bioenv/lib/python3.8/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2025.1.31)
# Requirement already satisfied: h11<0.15,>=0.13 in ./bioenv/lib/python3.8/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.14.0)
# Requirement already satisfied: appnope in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: nest-asyncio in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (6.1.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.7)
# Requirement already satisfied: ipython>=7.23.1 in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (8.12.3)
# Requirement already satisfied: comm>=0.1.1 in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.12)
# Requirement already satisfied: attrs>=22.2.0 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (25.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.20.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2023.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./bioenv/lib/python3.8/site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./bioenv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.2.1)
# Requirement already satisfied: rfc3339-validator in ./bioenv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./bioenv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./bioenv/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./bioenv/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.3)
# Requirement already satisfied: ptyprocess in ./bioenv/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.50)
# Requirement already satisfied: pickleshare in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: decorator in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (4.9.0)
# Requirement already satisfied: stack-data in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.6.3)
# Requirement already satisfied: backcall in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: isoduration in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (24.8.0)
# Requirement already satisfied: uri-template in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: fqdn in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in ./bioenv/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.17.1)
# Requirement already satisfied: pycparser in ./bioenv/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./bioenv/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: wcwidth in ./bioenv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in ./bioenv/lib/python3.8/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./bioenv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: pure-eval in ./bioenv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in ./bioenv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./bioenv/lib/python3.8/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.9.0.20241206)
# Installing collected packages: jupyter_highlight_selected_word, ipython_genutils, lxml, jupyter_contrib_core, jupyter_nbextensions_configurator, jupyter_contrib_nbextensions
#   DEPRECATION: jupyter_contrib_core is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for jupyter_contrib_core ... done
#   DEPRECATION: jupyter_contrib_nbextensions is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for jupyter_contrib_nbextensions ... one
# Successfully installed ipython_genutils-0.2.0 jupyter_contrib_core-0.4.2 jupyter_contrib_nbextensions-0.7.0 jupyter_highlight_selected_word-0.2.0 jupyter_nbextensions_configurator-0.6.4 lxml-5.3.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter contrib nbextension install --user
# Out:
#   Cell In[7], line 1
#     jupyter contrib nbextension install --user
#             ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade notebook biopython
# Out:
# Requirement already satisfied: notebook in ./bioenv/lib/python3.8/site-packages (7.3.2)
# Requirement already satisfied: biopython in ./bioenv/lib/python3.8/site-packages (1.83)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./bioenv/lib/python3.8/site-packages (from notebook) (0.2.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./bioenv/lib/python3.8/site-packages (from notebook) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./bioenv/lib/python3.8/site-packages (from notebook) (2.27.3)
# Requirement already satisfied: tornado>=6.2.0 in ./bioenv/lib/python3.8/site-packages (from notebook) (6.4.2)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in ./bioenv/lib/python3.8/site-packages (from notebook) (4.3.5)
# Requirement already satisfied: numpy in ./bioenv/lib/python3.8/site-packages (from biopython) (1.24.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: traitlets>=5.6.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.5.2)
# Requirement already satisfied: argon2-cffi>=21.1 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: nbformat>=5.3.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: terminado>=0.8.3 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: overrides>=5.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: jinja2>=3.0.3 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.5)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.6)
# Requirement already satisfied: pyzmq>=24 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.2.1)
# Requirement already satisfied: prometheus-client>=0.9 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.21.1)
# Requirement already satisfied: packaging>=22.0 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.2)
# Requirement already satisfied: send2trash>=1.8.2 in ./bioenv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: ipykernel>=6.5.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (6.29.5)
# Requirement already satisfied: importlib-resources>=1.4 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (6.4.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (2.2.5)
# Requirement already satisfied: setuptools>=40.8.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (56.0.0)
# Requirement already satisfied: tomli>=1.2.2 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (2.2.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (8.5.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (0.28.1)
# Requirement already satisfied: requests>=2.31 in ./bioenv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: jsonschema>=4.18.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: json5>=0.9.0 in ./bioenv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.10.0)
# Requirement already satisfied: babel>=2.10 in ./bioenv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.17.0)
# Requirement already satisfied: typing-extensions>=4.1 in ./bioenv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (4.12.2)
# Requirement already satisfied: idna>=2.8 in ./bioenv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./bioenv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./bioenv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./bioenv/lib/python3.8/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in ./bioenv/lib/python3.8/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook) (2025.1)
# Requirement already satisfied: certifi in ./bioenv/lib/python3.8/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in ./bioenv/lib/python3.8/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./bioenv/lib/python3.8/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in ./bioenv/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyterlab<4.4,>=4.3.4->notebook) (3.20.2)
# Requirement already satisfied: appnope in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.1.4)
# Requirement already satisfied: ipython>=7.23.1 in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (8.12.3)
# Requirement already satisfied: comm>=0.1.1 in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.2.2)
# Requirement already satisfied: nest-asyncio in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (1.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (1.8.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.1.7)
# Requirement already satisfied: psutil in ./bioenv/lib/python3.8/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (6.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./bioenv/lib/python3.8/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (2.1.5)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (1.3.10)
# Requirement already satisfied: attrs>=22.2.0 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (25.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.20.1)
# Requirement already satisfied: referencing>=0.28.4 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./bioenv/lib/python3.8/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./bioenv/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.3.6)
# Requirement already satisfied: rfc3339-validator in ./bioenv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./bioenv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (3.2.1)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./bioenv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: pyyaml>=5.3 in ./bioenv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.13.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.1.0)
# Requirement already satisfied: pygments>=2.4.1 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.19.1)
# Requirement already satisfied: jupyterlab-pygments in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.1.1)
# Requirement already satisfied: defusedxml in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in ./bioenv/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.1)
# Requirement already satisfied: fastjsonschema>=2.15 in ./bioenv/lib/python3.8/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./bioenv/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./bioenv/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.2.3)
# Requirement already satisfied: ptyprocess in ./bioenv/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: webencodings in ./bioenv/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in ./bioenv/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: tinycss2<1.3,>=1.1.0 in ./bioenv/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: jedi>=0.16 in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.19.2)
# Requirement already satisfied: backcall in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.2.0)
# Requirement already satisfied: pickleshare in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (4.9.0)
# Requirement already satisfied: stack-data in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (3.0.50)
# Requirement already satisfied: decorator in ./bioenv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (5.1.1)
# Requirement already satisfied: webcolors>=24.6.0 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (24.8.0)
# Requirement already satisfied: uri-template in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (3.0.0)
# Requirement already satisfied: isoduration in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (20.11.0)
# Requirement already satisfied: fqdn in ./bioenv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in ./bioenv/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in ./bioenv/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.6)
# Requirement already satisfied: pycparser in ./bioenv/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./bioenv/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.8.4)
# Requirement already satisfied: wcwidth in ./bioenv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in ./bioenv/lib/python3.8/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (1.3.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./bioenv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in ./bioenv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (2.2.0)
# Requirement already satisfied: pure-eval in ./bioenv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./bioenv/lib/python3.8/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2.9.0.20241206)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
